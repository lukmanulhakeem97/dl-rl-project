# %%
# !pip install -q condacolab

# %%
# https://www.datasciencelearner.com/change-python-version-in-google-colab-steps/
# Out:
# update-alternatives: --install needs <link> <name> <path> <priority>
#
# Use 'update-alternatives --help' for program usage information.

# %%
# first install python 3.6
# !sudo apt-get update -y
# !sudo apt-get install python3.6
# change alternatives
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.6 1
# select python version
# !sudo update-alternatives --config python3
# check python version
# !python --version
# install pip for new python 
# !sudo apt-get install python3.6-distutils
# !wget https://bootstrap.pypa.io/get-pip.py
# !python get-pip.py
# upgrade pip
# !sudo apt install python3-pip
# !python -m pip install --upgrade pip
# Out:
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:6 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:7 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Hit:10 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:11 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,150 kB]
# ...

# %%
# !python --version
# Out:
# Python 3.6.15

# %%
import condacolab

# %%
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %%
# !conda list

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation/
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation

# %%
# !git clone https://github.com/rll/rllab.git
# Out:
# Cloning into 'rllab'...
# remote: Enumerating objects: 1393, done.
# remote: Total 1393 (delta 0), reused 0 (delta 0), pack-reused 1393
# Receiving objects: 100% (1393/1393), 1.52 MiB | 7.95 MiB/s, done.
# Resolving deltas: 100% (757/757), done.
# Updating files: 100% (350/350), done.

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %cd rllab
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation/rllab

# %%
# !git checkout b3a28992eca103cab3cb58363dd7a4bb07f250a0
# Out:
# M	rllab/mujoco_py/gen_binding.sh
# M	scripts/setup_linux.sh
# M	scripts/setup_mujoco.sh
# M	scripts/setup_osx.sh
# HEAD is now at b3a2899 Setup fix (#186)

# %%
# !export PYTHONPATH=$(pwd):${PYTHONPATH}

# %%
# %mkdir -p /tmp/mujoco_tmp && cd /tmp/mujoco_tmp

# %%
# !wget -P . https://www.roboti.us/download/mjpro131_linux.zip
# !unzip mjpro131_linux.zip
# Out:
# --2023-04-25 02:49:41--  https://www.roboti.us/download/mjpro131_linux.zip
# Resolving www.roboti.us (www.roboti.us)... 104.40.85.93
# Connecting to www.roboti.us (www.roboti.us)|104.40.85.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 882304 (862K) [application/zip]
# Saving to: ‘./mjpro131_linux.zip’
#
# mjpro131_linux.zip  100%[===================>] 861.62K  2.74MB/s    in 0.3s
#
# 2023-04-25 02:49:42 (2.74 MB/s) - ‘./mjpro131_linux.zip’ saved [882304/882304]
#
# Archive:  mjpro131_linux.zip
#    creating: mjpro131/
#    creating: mjpro131/sample/
#   inflating: mjpro131/sample/makefile
#   inflating: mjpro131/sample/compile.cpp
#   inflating: mjpro131/sample/test.cpp
#   inflating: mjpro131/sample/simulate.cpp
#    creating: mjpro131/model/
#   inflating: mjpro131/model/humanoid.xml
#    creating: mjpro131/include/
#   inflating: mjpro131/include/glfw3.h
#   inflating: mjpro131/include/mujoco.h
#   inflating: mjpro131/include/mjxmacro.h
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation/rllab'

# %%
# %ls
# Out:
# CHANGELOG.md  docker/          examples/  mjpro131_linux.zip  sandbox/  tests/
# circle.yml    docs/            LICENSE    README.md           scripts/  vendor/
# contrib/      environment.yml  mjpro131/  rllab/              setup.py

# %%
# %mkdir /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation/rllab/vendor/mujoco
# %cp ./mjpro131/bin/libmujoco131.so /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation/rllab/vendor/mujoco
# %cp ./mjpro131/bin/libglfw.so.3 /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation/rllab/vendor/mujoco

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation/rllab'

# %%
# %cd ..
# %rm -rf /tmp/mujoco_tmp
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation

# %%
#%cp <mujoco_key_folder>/mjkey.txt <installation_path_of_your_choice>/rllab/vendor/mujoco

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation

# %%
# !git clone https://github.com/haarnoja/softqlearning.git
# Out:
# Cloning into 'softqlearning'...
# remote: Enumerating objects: 521, done.
# remote: Total 521 (delta 0), reused 0 (delta 0), pack-reused 521
# Receiving objects: 100% (521/521), 191.32 KiB | 2.25 MiB/s, done.
# Resolving deltas: 100% (262/262), done.

# %%
# %cd softqlearning
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/haarnoja-implementation/softqlearning

# %%
# !conda env update -n base -f environment.yml
# Out:
# /bin/bash: conda: command not found

# %%
# !conda install -c anaconda cached-property

# %%
# !conda install -c anaconda cloudpickle

# %%
# !conda install -c anaconda conda==23.1.0

# %%
# !conda install -c anaconda conda==23.1.0

# %%
# !conda install -c anaconda mamba==1.4.1

# %%
# !conda install -c anaconda numpy==1.14.5
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - numpy==1.14.5 -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#
# Your python: python=3.10
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.

# %%
# !conda install -c anaconda path.py

# %%
# !source activate sql
# Out:
# EnvironmentNameNotFound: Could not find conda environment: sql
# You can list all discoverable environments with `conda info --envs`.

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                     /usr/local

# %%
# !import numpy

# %%
numpy.__version__
# Out:
# '1.22.4'

# %%
n

# %%
import cloudpickle
