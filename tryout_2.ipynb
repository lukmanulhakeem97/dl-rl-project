# %%
# %cd
# Out:
# /root

# %%
# %pwd
# Out:
# '/content'

# %%
# %ls

# %%
# %mkdir .mujoco

# %%
# !wget https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# Out:
# --2023-04-22 15:09:09--  https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# Resolving mujoco.org (mujoco.org)... 216.239.38.21, 216.239.36.21, 216.239.34.21, ...
# Connecting to mujoco.org (mujoco.org)|216.239.38.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-tar]
# Saving to: ‘mujoco210-linux-x86_64.tar.gz’
#
# mujoco210-linux-x86     [            <=>     ]   4.18M  1.55MB/s    in 2.7s
#
# 2023-04-22 15:09:13 (1.55 MB/s) - ‘mujoco210-linux-x86_64.tar.gz’ saved [4385135]

# %%
# !tar -xvf mujoco210-linux-x86_64.tar.gz -C ~/.mujoco/
# Out:
# mujoco210/
# mujoco210/THIRD_PARTY_NOTICES
# mujoco210/bin/
# mujoco210/bin/libglfw.so.3
# mujoco210/bin/derivative
# mujoco210/bin/libglew.so
# mujoco210/bin/record
# mujoco210/bin/simulate
# mujoco210/bin/libglewegl.so
# mujoco210/bin/testxml
# mujoco210/bin/basic
# mujoco210/bin/libglewosmesa.so
# mujoco210/bin/libglfw3.a
# mujoco210/bin/libmujoco210.so
# mujoco210/bin/compile
# mujoco210/bin/libmujoco210nogl.so
# mujoco210/bin/testspeed
# mujoco210/include/
# mujoco210/include/glfw3.h
# mujoco210/include/uitools.c
# mujoco210/include/mjxmacro.h
# mujoco210/include/mjui.h
# mujoco210/include/mjrender.h
# mujoco210/include/mjmodel.h
# mujoco210/include/mjdata.h
# mujoco210/include/mujoco.h
# mujoco210/include/mjvisualize.h
# mujoco210/include/uitools.h
# mujoco210/model/
# mujoco210/model/humanoid100.xml
# mujoco210/model/arm26.xml
# mujoco210/model/carpet.png
# mujoco210/model/softbox.xml
# mujoco210/model/grid2pin.xml
# mujoco210/model/sponge.png
# mujoco210/model/hammock.xml
# ...

# %%
# %cd .mujoco
# Out:
# /root/.mujoco

# %%
# %ls
# Out:
# mujoco210/

# %%
# %cd
# Out:
# /root

# %%
# %cd .mujoco
# Out:
# /root/.mujoco

# %%
# %cd mujoco210
# Out:
# /root/.mujoco/mujoco210

# %%
# %ls
# Out:
# mujoco210-linux-x86_64.tar.gz

# %%
# %cd
# Out:
# /root

# %%
# !echo -e 
# !export LD_LIBRARY_PATH=/home/user-name/.mujoco/mujoco210/bin

# %%
#!echo -e 'export LD_LIBRARY_PATH=/home/user-name/.mujoco/mujoco210/bin 
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/lib/nvidia 
# !export PATH="$LD_LIBRARY_PATH:$PATH" 
# !export LD_PRELOAD=/usr/lib/x86_64-linux-gnu/libGLEW.so >> ~/.bashrc

# %%
# !source ~/.bashrc

# %%
# %cd ~/.mujoco/mujoco210/bin
# Out:
# /root/.mujoco/mujoco210/bin

# %%
# %ls
# Out:
# basic*       libglewegl.so     libglfw3.a           libmujoco210.so  simulate*
# compile*     libglewosmesa.so  libglfw.so.3         MUJOCO_LOG.TXT   testspeed*
# derivative*  libglew.so        libmujoco210nogl.so  record*          testxml*

# %%
# %pwd
# Out:
# '/root/.mujoco/mujoco210'

# %%
# %cd bin
# Out:
# /root/.mujoco/mujoco210/bin

# %%
cd ~/.mujoco/mujoco210/bin
./simulate ../model/humanoid.xml

# %%
# !export DISPLAY=:2

# %%
# !./simulate ../model/humanoid.xml
# Out:
# MuJoCo Pro version 2.10
# ERROR: could not initialize GLFW
#
# Press Enter to exit ...

# %%
# %cd /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton

# %% [markdown]
# Taken from: https://gist.github.com/saratrajput/60b1310fe9d9df664f9983b38b50d5da
