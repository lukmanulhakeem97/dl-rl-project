# %%
# %pwd
# Out:
# '/content'

# %%
# %cd
# Out:
# /root

# %%
# %rm -r .mujoco

# %%
# %rm -r mujoco210

# %%
# %ls

# %%
# %mkdir .mujoco
# Out:
# mkdir: cannot create directory ‘.mujoco’: File exists

# %%
# %cd .mujoco/
# Out:
# /root/.mujoco

# %%
# !wget https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# Out:
# --2023-04-14 10:11:41--  https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz
# Resolving mujoco.org (mujoco.org)... 216.239.36.21, 216.239.34.21, 216.239.32.21, ...
# Connecting to mujoco.org (mujoco.org)|216.239.36.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-tar]
# Saving to: ‘mujoco210-linux-x86_64.tar.gz’
#
# mujoco210-linux-x86     [ <=>                ]   4.18M  --.-KB/s    in 0.07s
#
# 2023-04-14 10:11:41 (56.0 MB/s) - ‘mujoco210-linux-x86_64.tar.gz’ saved [4385135]

# %%
# %ls
# Out:
# mujoco210/  mujoco210-linux-x86_64.tar.gz

# %%
! tar xvzf mujoco210-linux-x86_64.tar.gz
# Out:
# mujoco210/
# mujoco210/THIRD_PARTY_NOTICES
# mujoco210/bin/
# mujoco210/bin/libglfw.so.3
# mujoco210/bin/derivative
# mujoco210/bin/libglew.so
# mujoco210/bin/record
# mujoco210/bin/simulate
# mujoco210/bin/libglewegl.so
# mujoco210/bin/testxml
# mujoco210/bin/basic
# mujoco210/bin/libglewosmesa.so
# mujoco210/bin/libglfw3.a
# mujoco210/bin/libmujoco210.so
# mujoco210/bin/compile
# mujoco210/bin/libmujoco210nogl.so
# mujoco210/bin/testspeed
# mujoco210/include/
# mujoco210/include/glfw3.h
# mujoco210/include/uitools.c
# mujoco210/include/mjxmacro.h
# mujoco210/include/mjui.h
# mujoco210/include/mjrender.h
# mujoco210/include/mjmodel.h
# mujoco210/include/mjdata.h
# mujoco210/include/mujoco.h
# mujoco210/include/mjvisualize.h
# mujoco210/include/uitools.h
# mujoco210/model/
# mujoco210/model/humanoid100.xml
# mujoco210/model/arm26.xml
# mujoco210/model/carpet.png
# mujoco210/model/softbox.xml
# mujoco210/model/grid2pin.xml
# mujoco210/model/sponge.png
# mujoco210/model/hammock.xml
# ...

# %%
# %ls
# Out:
# mujoco210/  mujoco210-linux-x86_64.tar.gz

# %%
# %rm -r mujoco210-linux-x86_64.tar.gz

# %%
# %cd ..
# Out:
# /

# %%
# %rm -r mujoco210-linux-x86_64.tar.gz

# %%
# %cd .mujoco/
# Out:
# /root/.mujoco

# %%
# %cd
# Out:
# /root

# %%
# %cd /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/S2/DL-and-RL/project/implementaiton'

# %%
# !git clone https://github.com/rail-berkeley/softlearning.git
# Out:
# Cloning into 'softlearning'...
# remote: Enumerating objects: 10155, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 10155 (delta 20), reused 4 (delta 0), pack-reused 10121
# Receiving objects: 100% (10155/10155), 13.42 MiB | 8.46 MiB/s, done.
# Resolving deltas: 100% (7144/7144), done.

# %%
# %ls
# Out:
# softlearning/

# %%
wsx2

# %%
#!wget https://gist.githubusercontent.com/BuildingAtom/3119ac9c595324c8001a7454f23bf8c8/raw/688b5f96205f6867a40e1fa0f586a2cb5e152bc9/google-colab-mujoco-py-setup.py

# %%
# %cd softlearning
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/softlearning

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/S2/DL-and-RL/project/implementaiton'

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.8/127.8 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 406.0/406.0 kB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.0/202.0 kB 20.2 MB/s eta 0:00:00
# ...

# %%
#!pip3 install mujoco-py==2.1.0
# !pip3 install --user mujoco-py==2.0.2.8
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 54.5 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# softlearning 0.0.1 requires mujoco-py>=2.0.2.10, but you have mujoco-py 2.0.2.8 which is incompatible.
# ...

# %%
# %cd softlearning
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/softlearning

# %%
# !python setup.py install
# Out:
# ...
# running install
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# writing softlearning.egg-info/PKG-INFO
# writing dependency_links to softlearning.egg-info/dependency_links.txt
# writing entry points to softlearning.egg-info/entry_points.txt
# writing requirements to softlearning.egg-info/requires.txt
# writing top-level names to softlearning.egg-info/top_level.txt
# reading manifest file 'softlearning.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'softlearning.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# ...

# %%
# !softlearning run_example_local examples.development \
    --algorithm SAC \
    --universe gym \
    --domain HalfCheetah \
    --task v3 \
    --exp-name my-sac-experiment-1 \
    --checkpoint-frequency 1000  # Save the checkpoint to resume training later
# Out:
# 2023-04-14 11:07:03.235568: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-14 11:07:04.253067: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/local/bin/softlearning", line 33, in <module>
#     sys.exit(load_entry_point('softlearning==0.0.1', 'console_scripts', 'softlearning')())
#   File "/usr/local/lib/python3.9/dist-packages/softlearning-0.0.1-py3.9.egg/softlearning/scripts/console_scripts.py", line 207, in main
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1130, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1055, in main
# ...

# %%
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco210/bin
# Out:
# UsageError: Line magic function `%export` not found.

# %%
! echo $LD_LIBRARY_PATH

import os
os.environ['LD_LIBRARY_PATH']=os.environ['LD_LIBRARY_PATH'] + ':/root/.mujoco/mujoco210/bin'

! echo $LD_LIBRARY_PATH
# Out:
# /usr/lib64-nvidia
# /usr/lib64-nvidia:/root/.mujoco/mujoco210/bin

# %%
# !sudo apt-get install libosmesa6-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libosmesa6-dev is already the newest version (21.2.6-0ubuntu0.1~20.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
# !sudo apt-get install patchelf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# patchelf is already the newest version (0.10-2build1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
# !softlearning run_example_local examples.development \
    --algorithm SAC \
    --universe gym \
    --domain HalfCheetah \
    --task v3 \
    --exp-name my-sac-experiment-1 \
    --checkpoint-frequency 1000
# Out:
# 2023-04-14 11:08:04.460886: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-14 11:08:05.934103: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/gym/envs/registration.py:440: UserWarning: WARN: The `registry.env_specs` property along with `EnvSpecTree` is deprecated. Please use `registry` directly as a dictionary instead.
#   logger.warn(
# INFO:absl:MUJOCO_GL is not set, so an OpenGL backend will be chosen automatically.
# /usr/local/lib/python3.9/dist-packages/glfw/__init__.py:916: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# INFO:absl:Successfully imported OpenGL backend: glfw
# ...
