# %%
# %cd /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton

# %%
# !git clone https://github.com/lukmanulhakeem97/Continuous-RL.git
# Out:
# Cloning into 'Continuous-RL'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 179 (delta 59), reused 149 (delta 32), pack-reused 0
# Receiving objects: 100% (179/179), 13.36 MiB | 13.75 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !pip install pybullet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/Continuous-RL

# %%
# %cd ./Continuous-RL/Algorithms/SQL/Code
# Out:
# /content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/Continuous-RL/Algorithms/SQL/Code

# %%
# !python main_SQL.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/S2/DL-and-RL/project/implementaiton/Continuous-RL/Algorithms/SQL/Code/main_SQL.py", line 4, in <module>
#     import pybulletgym
# ModuleNotFoundError: No module named 'pybulletgym'
